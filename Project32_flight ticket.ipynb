# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Read files:
train = pd.read_excel(r"C:\Users\PRATIK PANIGRAHI\Desktop\Train.xlsx")
test = pd.read_excel(r"C:\Users\PRATIK PANIGRAHI\Desktop\Test.xlsx")

# %%
train
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# 5               SpiceJet      24/06/2019   Kolkata    Banglore
# 6            Jet Airways      12/03/2019  Banglore   New Delhi
# 7            Jet Airways      01/03/2019  Banglore   New Delhi
# 8            Jet Airways      12/03/2019  Banglore   New Delhi
# 9      Multiple carriers      27/05/2019     Delhi      Cochin
# 10             Air India       1/06/2019     Delhi      Cochin
# 11                IndiGo      18/04/2019   Kolkata    Banglore
# 12             Air India      24/06/2019   Chennai     Kolkata
# 13           Jet Airways       9/05/2019   Kolkata    Banglore
# ...

# %%
test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# 5           Jet Airways      12/06/2019     Delhi      Cochin
# 6             Air India      12/03/2019  Banglore   New Delhi
# 7                IndiGo       1/05/2019   Kolkata    Banglore
# 8                IndiGo      15/03/2019   Kolkata    Banglore
# 9           Jet Airways      18/05/2019   Kolkata    Banglore
# 10          Jet Airways      21/03/2019     Delhi      Cochin
# 11               IndiGo      15/06/2019     Delhi      Cochin
# 12    Multiple carriers      15/05/2019     Delhi      Cochin
# 13          Jet Airways      12/03/2019  Banglore   New Delhi
# ...

# %% [markdown]
# # Data Exploration

# %%
train.shape
# Out:
# (10683, 11)

# %%
test.shape
# Out:
# (2671, 10)

# %%
train.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# As we can see there are missing value present in the train data.

# %%
train.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
test.describe()
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count          2671            2671   2671        2671             2671
# unique           11              44      5           6              100
# top     Jet Airways       9/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq            897             144   1145        1145              624
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count      2671         2671     2671        2671            2671
# unique      199          704      320           5               6
# top       10:00        19:00   2h 50m      1 stop         No info
# freq         62          113      122        1431            2148

# %%
#missing value treatment for train data
train["Route"] =train["Route"].fillna((train["Route"].mode()[0]))
train["Total_Stops"]=train["Total_Stops"].fillna((train["Total_Stops"].mode()[0]))
train.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
#changing categorical value to numerical value of train data
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for col in train.columns:
    train[col]=le.fit_transform(train[col])
train.head()
# Out:
#    Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        3               24       0            5     18       211
# 1        1                6       3            0     84        31
# 2        4               43       2            1    118        70
# 3        3               10       3            0     91       164
# 4        3                0       0            5     29       149
#
#    Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0           233       240            4                8     65
# 1           906       336            1                8    669
# 2           413       106            1                8   1537
# 3          1324       311            0                8    389
# 4          1237       303            0                8   1457

# %%
#changing categorical value to numerical value of test data
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for col in test.columns:
    test[col]=le.fit_transform(test[col])
test.head()
# Out:
#    Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        4               39       2            1     76       138
# 1        3               10       3            0     65        31
# 2        4               22       2            1     76       156
# 3        6               22       2            1     76        48
# 4        0               27       0            2     16       198
#
#    Arrival_Time  Duration  Total_Stops  Additional_Info
# 0           150        10            0                5
# 1           353       248            0                5
# 2           566       148            0                3
# 3           633        36            0                5
# 4           135       216            4                5

# %%
train.hist(figsize=(20,10),grid=True,layout=(2,6),bins=30)
plt.show()

# %%
test.hist(figsize=(20,10),grid=False,layout=(2,6),bins=30)
plt.show()

# %%
sns.distplot(train['Price'])

# %% [markdown]
# #The histogram graph of price is widely spread.

# %%
train.groupby('Total_Stops')['Price'].mean().plot.bar()

# %%
sns.countplot(x="Total_Stops", data= train)

# %%
sns.heatmap(train.corr(),annot = True)
plt.show()

# %%
data.head()
# Out:
#    Additional_Info  Airline  Arrival_Time  Date_of_Journey  Dep_Time  \
# 0                8        3           233               24       211
# 1                8        1           906                6        31
# 2                8        4           413               43        70
# 3                8        3          1324               10       164
# 4                8        3          1237                0       149
#
#    Destination  Duration   Price  Route  Source  Total_Stops
# 0            5       240    65.0     18       0            4
# 1            0       336   669.0     84       3            1
# 2            1       106  1537.0    118       2            1
# 3            0       311   389.0     91       3            0
# 4            5       303  1457.0     29       0            0

# %%
train.shape
# Out:
# (10683, 11)

# %%
test.shape
# Out:
# (2671, 10)

# %%
train.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
for col in train.columns:
    train[col]=pd.to_numeric(train[col],errors='coerce')

# %%
test.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %%
for col in test.columns:
    test[col]=pd.to_numeric(test[col],errors='coerce')

# %%
test["Price"] = ""

# %%
test.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
x_train=train.drop('Price',axis=1)
y_train=train['Price']
x_test=test.drop('Price',axis=1)
y_test=test['Price']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_selection import SelectKBest

# %%
x_train.dtypes
# Out:
# Airline            int32
# Date_of_Journey    int32
# Source             int32
# Destination        int32
# Route              int32
# Dep_Time           int32
# Arrival_Time       int32
# Duration           int32
# Total_Stops        int32
# Additional_Info    int32
# dtype: object

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (10683, 10)
# (10683,)
# (2671, 10)
# (2671,)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# modeling utilities
from sklearn import tree
from sklearn import metrics
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
dtr = DecisionTreeRegressor(max_depth=4,
                            min_samples_split=5,
                            max_leaf_nodes=10)
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#                       max_leaf_nodes=10, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=5, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %% [markdown]
# # Grid Search CV

# %%
dtr.score(x_train, y_train)
# Out:
# 0.7313313497513999

# %%
param_grid = {"criterion": ["mse", "mae"]
                 }

# %%
dtr= DecisionTreeRegressor()

# %%
grid_cv_dtr = GridSearchCV(dtr, param_grid, cv=5)

# %%
grid_cv_dtr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=None, param_grid={'criterion': ['mse', 'mae']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("R-Squared::{}".format(grid_cv_dtr.best_score_))
print("Best Hyperparameters::\n{}".format(grid_cv_dtr.best_params_))
# Out:
# R-Squared::0.867618234896364
# Best Hyperparameters::
# {'criterion': 'mse'}

# %%
r2_scores = cross_val_score(grid_cv_dtr.best_estimator_, x_train, y_train, cv=10)
mse_scores = cross_val_score(grid_cv_dtr.best_estimator_, x_train, y_train, cv=10,scoring='neg_mean_squared_error')

# %%
print("avg R-squared::{}".format(np.mean(r2_scores)))
print("MSE::{}".format(np.mean(mse_scores)))
# Out:
# avg R-squared::0.868256239651363
# MSE::-42626.99511966547

# %%
grid_cv_dtr.score(x_train,y_train)
# Out:
# 0.9938159059374218

# %%
#model saving
from sklearn.externals import joblib
# Out:
# C:\Users\PRATIK PANIGRAHI\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
joblib.dump(grid_cv_dtr, "Project32_flight ticket.pkl")
# Out:
# ['Project32_flight ticket.pkl']

# %%
x= joblib.load("Project32_flight ticket.pkl")

# %%
x.predict(x_test)
# Out:
# array([ 835.,   89., 1023., ..., 1686., 1250., 1117.])
