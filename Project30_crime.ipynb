# %%
import numpy as np # linear algebra
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\PRATIK PANIGRAHI\Desktop\20_Victims_of_rape.csv")
data
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# 5     Andaman & Nicobar Islands  2002   Victims of Other Rape
# 6     Andaman & Nicobar Islands  2003      Total Rape Victims
# 7     Andaman & Nicobar Islands  2003  Victims of Incest Rape
# 8     Andaman & Nicobar Islands  2003   Victims of Other Rape
# 9     Andaman & Nicobar Islands  2004      Total Rape Victims
# 10    Andaman & Nicobar Islands  2004  Victims of Incest Rape
# 11    Andaman & Nicobar Islands  2004   Victims of Other Rape
# 12    Andaman & Nicobar Islands  2005      Total Rape Victims
# 13    Andaman & Nicobar Islands  2005  Victims of Incest Rape
# ...

# %% [markdown]
# # DataExploration

# %%
data.shape
# Out:
# (1050, 11)

# %%
data.keys()
# Out:
# Index(['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported',
#        'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs',
#        'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs',
#        'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total',
#        'Victims_Upto_10_Yrs'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# configure matplotlib to output inline
# %matplotlib inline

# %%
# let's see how the data is structur
data.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
# clean the data 
# we don't need the Total Rape Victims subgroup
data = data[data['Subgroup'] != 'Total Rape Victims']

# %%
#check if the all the rape cases are reported
data[data['Victims_of_Rape_Total'] != data['Rape_Cases_Reported']].head()
# Out:
#       Area_Name  Year               Subgroup  Rape_Cases_Reported  \
# 152  Chandigarh  2001  Victims of Other Rape                   16
# 272       Delhi  2001  Victims of Other Rape                  372
# 275       Delhi  2002  Victims of Other Rape                  371
# 284       Delhi  2005  Victims of Other Rape                  626
# 287       Delhi  2006  Victims of Other Rape                  597
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 152                     0                          8
# 272                     0                         78
# 275                     0                         48
# 284                     2                        111
# 287                     2                        107
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 152                          4                          2
# 272                        152                         58
# 275                         40                        207
# ...

# %%
data['Unreported_Cases'] = data['Victims_of_Rape_Total'] - data['Rape_Cases_Reported']

# let's taka a look at the new dataframe
data[data['Unreported_Cases'] > 0].head()
# Out:
# C:\Users\PRATIK PANIGRAHI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       Area_Name  Year               Subgroup  Rape_Cases_Reported  \
# 152  Chandigarh  2001  Victims of Other Rape                   16
# 272       Delhi  2001  Victims of Other Rape                  372
# 275       Delhi  2002  Victims of Other Rape                  371
# 284       Delhi  2005  Victims of Other Rape                  626
# 287       Delhi  2006  Victims of Other Rape                  597
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 152                     0                          8
# 272                     0                         78
# ...

# %%
# let's plot the unreported rape cases sorted by states throughout 2001 to 2010
unreported_victims_by_state = data.groupby('Area_Name').sum()
unreported_victims_by_state.drop('Year', axis = 1, inplace = True)

# %%
# let's finally plot it
plt.subplots(figsize = (15, 6))
ct = unreported_victims_by_state[unreported_victims_by_state['Unreported_Cases'] 
                                 > 0]['Unreported_Cases'].sort_values(ascending = False)
#print(ct)
ax = ct.plot.bar()
ax.set_xlabel('Area Name')
ax.set_ylabel('Total Number of Unreported Rape Victims from 2001 to 2010')
ax.set_title('Statewise total Unreported Rape Victims throughout 2001 to 2010')
plt.show()

# %%
# take some general data and plot some simple charts
rape_victims_by_state = data.groupby('Area_Name').sum()
rape_victims_by_state.drop('Year', axis = 1, inplace = True)
print('Total Rape Victims = ' ,rape_victims_by_state['Rape_Cases_Reported'].sum())
rape_victims_by_state.sort_values(by = 'Rape_Cases_Reported', ascending = False).head()
# Out:
# Total Rape Victims =  190008
#                 Rape_Cases_Reported  Victims_Above_50_Yrs  \
# Area_Name
# Madhya Pradesh                29256                   181
# West Bengal                   16378                    10
# Uttar Pradesh                 15053                    12
# Maharashtra                   14446                    63
# Assam                         12762                    95
#
#                 Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# Area_Name
# Madhya Pradesh                       2499                       5554
# West Bengal                           156                        273
# Uttar Pradesh                        1424                       3092
# Maharashtra                          1305                       4152
# Assam                                 153                        409
#
#                 Victims_Between_18-30_Yrs  Victims_Between_30-50_Yrs  \
# Area_Name
# ...

# %%
# let's make a heatmap variable
rape_victims_heatmap = rape_victims_by_state.drop(['Rape_Cases_Reported', 
                                                   'Victims_of_Rape_Total', 
                                                   'Unreported_Cases'], axis = 1)
plt.subplots(figsize = (10, 10))
ax = sns.heatmap(rape_victims_heatmap, cmap="Blues")
ax.set_xlabel('Age Group')
ax.set_ylabel('State Name')
ax.set_title('Statewise Victims of Rape Cases based on Age Group')
plt.show()

# %% [raw]
# (1)In the above Diagram we can observe that victims between 18 to 30 years are from MadhyaPradesh and West Bengal.
# (2)And the 2nd highest victims comes under in Assam and Bihar.
# (3)Victims between 30 to 50 yrs , in MadhyaPradesh highest no of case is registered.

# %%
# let's first plot only the total number of rape cases reported in each state
plt.subplots(figsize = (15, 6))
ct = rape_victims_by_state['Rape_Cases_Reported'].sort_values(ascending = False)
#print(ct)
ax = ct.plot.bar()
#ax = sns.barplot(x = rape_victims_by_state.index, y = rape_victims_by_state['Rape_Cases_Reported'])
ax.set_xlabel('Area Name')
ax.set_ylabel('Total Number of Reported Rape Victims from 2001 to 2010')
ax.set_title('Statewise total Reported Rape Victims throught the Years 2001 to 2010')
plt.show()
print(ct)
# Out:
# Area_Name
# Madhya Pradesh               29256
# West Bengal                  16378
# Uttar Pradesh                15053
# Maharashtra                  14446
# Assam                        12762
# Rajasthan                    11949
# Bihar                        11263
# Andhra Pradesh               10696
# Chhattisgarh                  9751
# Odisha                        8860
# Jharkhand                     7563
# Tamil Nadu                    5538
# Kerala                        5296
# Delhi                         5146
# Haryana                       5009
# Punjab                        4300
# Karnataka                     3917
# Gujarat                       3337
# Jammu & Kashmir               2230
# Tripura                       1624
# Himachal Pradesh              1453
# Uttarakhand                   1101
# Meghalaya                      726
# Mizoram                        646
# Arunachal Pradesh              412
# Manipur                        271
# ...

# %% [markdown]
# As we can see through out the year 2001 to 2010 In MadhyaPradesh highest no of case is registured.

# %% [markdown]
# # Exploring Data for Madhya Pradesh

# %%
mp_rape_victims = data[data['Area_Name'] == 'Madhya Pradesh']

# let's have a look in the data
mp_rape_victims.head()
# Out:
#           Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 571  Madhya Pradesh  2001  Victims of Incest Rape                  301
# 572  Madhya Pradesh  2001   Victims of Other Rape                 2550
# 574  Madhya Pradesh  2002  Victims of Incest Rape                   72
# 575  Madhya Pradesh  2002   Victims of Other Rape                 2819
# 577  Madhya Pradesh  2003  Victims of Incest Rape                  123
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 571                     0                         39
# 572                    27                        265
# 574                     1                         11
# 575                    13                        174
# 577                     0                         10
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 571                         66                        130
# 572                        491                       1120
# ...

# %% [markdown]
# # Yearly plot of the number of rape victims in Madhya Pradesh

# %%
# Let's have a look at yearly distribution of number of rape victims in Madhya Pradesh
mp_rape_victims_by_year = mp_rape_victims.groupby('Year').sum()

# plotting the data
plt.subplots(figsize = (15, 6))
ax = mp_rape_victims_by_year['Rape_Cases_Reported'].plot()
ax.xaxis.set_ticks(np.arange(2001, 2011, 1))
ax.set(xlabel = 'Year', ylabel = 'Total Number of Reported Rape Victims', 
       title = 'Number of Rape Victims throught the years 2001 to 2010 of Madhya Pradesh')
plt.show()

# %% [markdown]
# # Yearly Distribution of Number of Incest Rape Victims in Madhya Pradesh

# %%
# let's first see the mp_rape_victims dataframe
#mp_rape_victims.head()

# plot the dataframe
mp_incest_rape_cases = mp_rape_victims[mp_rape_victims['Subgroup'] == 'Victims of Incest Rape']
plt.subplots(figsize = (15,6))
ct = mp_incest_rape_cases.groupby('Year').sum()
ax = ct['Rape_Cases_Reported'].plot.bar()
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.1, p.get_height()+2),fontsize=12)
ax.set_xlabel('Year')
ax.set_ylabel('Total Number of Incest Rape Victims from 2001 to 2010')
ax.set_title('Total Reported Incest Rape Victims of Madhya Pradesh throught the Years 2001 to 2010')
plt.show()

# %% [markdown]
# In 2001 there are nearly 301 case is registered and the second highest is in the year of 2005.

# %% [markdown]
# # Data for West Bengal

# %%
wb_rape_victims = data[data['Area_Name'] == 'West Bengal']

# Let's have a look at yearly distribution of number of rape victims in Madhya Pradesh
wb_rape_victims_by_year = wb_rape_victims.groupby('Year').sum()

# plotting the data
plt.subplots(figsize = (15, 6))
ax = wb_rape_victims_by_year['Rape_Cases_Reported'].plot()
ax.xaxis.set_ticks(np.arange(2001, 2011, 1))
ax.set(xlabel = 'Year', ylabel = 'Total Number of Reported Rape Victims',
       title = 'Number of Rape Victims throught the years 2001 to 2010 of West Bengal')
plt.show()

# %% [markdown]
# As the above graph shown by increasing year the rape cases is also increasing,slight slower in 2006.

# %%
# incest rape cases in Bengal
wb_incest_rape_cases = wb_rape_victims[wb_rape_victims['Subgroup'] == 'Victims of Incest Rape']
plt.subplots(figsize = (15,6))
ct = wb_incest_rape_cases.groupby('Year').sum()
ax = ct[ct['Rape_Cases_Reported'] > 0]['Rape_Cases_Reported'].plot.bar()
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x() + .15, p.get_height()+1),fontsize=13)
ax.set_xlabel('Year')
ax.set_ylabel('Total Number of Incest Rape Victims from 2001 to 2010')
ax.set_title('Total Reported Incest Rape Victims of West Bengal throught the Years 2001 to 2010')
plt.show()

# %% [raw]
# Unfortunately in the year 2007 there are highest no of case is registered of114.
# if we compare it to Madhya Pradesh, no incest rape cases were reported for the year 2001 an 2002.

# %%
stolen=pd.read_csv(r'C:\Users\PRATIK PANIGRAHI\Desktop\10_Property_stolen_and_recovered.csv')
stolen
# Out:
#                       Area_Name  Year           Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Burglary - Property
# 1                Andhra Pradesh  2001  Burglary - Property
# 2             Arunachal Pradesh  2001  Burglary - Property
# 3                         Assam  2001  Burglary - Property
# 4                         Bihar  2001  Burglary - Property
# 5                    Chandigarh  2001  Burglary - Property
# 6                  Chhattisgarh  2001  Burglary - Property
# 7          Dadra & Nagar Haveli  2001  Burglary - Property
# 8                   Daman & Diu  2001  Burglary - Property
# 9                         Delhi  2001  Burglary - Property
# 10                          Goa  2001  Burglary - Property
# 11                      Gujarat  2001  Burglary - Property
# 12                      Haryana  2001  Burglary - Property
# 13             Himachal Pradesh  2001  Burglary - Property
# 14              Jammu & Kashmir  2001  Burglary - Property
# ...

# %%
stolen.Area_Name.value_counts()
# Out:
# Punjab                       70
# Manipur                      70
# Tripura                      70
# Bihar                        70
# Andaman & Nicobar Islands    70
# Nagaland                     70
# Madhya Pradesh               70
# Arunachal Pradesh            70
# Karnataka                    70
# Maharashtra                  70
# Himachal Pradesh             70
# Chhattisgarh                 70
# Delhi                        70
# Odisha                       70
# Haryana                      70
# Jharkhand                    70
# Andhra Pradesh               70
# Meghalaya                    70
# Goa                          70
# West Bengal                  70
# Daman & Diu                  70
# Rajasthan                    70
# Sikkim                       70
# Jammu & Kashmir              70
# Dadra & Nagar Haveli         70
# Puducherry                   70
# Tamil Nadu                   70
# Mizoram                      70
# Kerala                       70
# ...

# %%
stolen.Year.value_counts()
# Out:
# 2009    245
# 2005    245
# 2003    245
# 2001    245
# 2010    245
# 2008    245
# 2006    245
# 2004    245
# 2002    245
# 2007    244
# Name: Year, dtype: int64

# %%
stolen.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Property_Recovered', 'Cases_Property_Stolen',
#        'Value_of_Property_Recovered', 'Value_of_Property_Stolen'],
#       dtype='object')

# %%
stolen.Year.value_counts()
# Out:
# 2009    245
# 2005    245
# 2003    245
# 2001    245
# 2010    245
# 2008    245
# 2006    245
# 2004    245
# 2002    245
# 2007    244
# Name: Year, dtype: int64

# %%
stolen.Group_Name.value_counts()
# Out:
# Dacoity -Property                      350
# Robbery - Property                     350
# Other heads of Property                350
# Theft - Property                       350
# Criminal Breach of Trust - Property    350
# Burglary - Property                    350
# Total Property                         349
# Name: Group_Name, dtype: int64

# %%
stolen.Sub_Group_Name.value_counts()
# Out:
# 4. Theft                                350
# 1. Dacoity                              350
# 3. Burglary                             350
# 6. Other Property                       350
# 5. Criminal Breach of Trust             350
# 2. Robbery                              350
# 7. Total Property Stolen & Recovered    349
# Name: Sub_Group_Name, dtype: int64

# %% [markdown]
# Group_Name and sub_Group Name have same no of instances.

# %%
a=stolen.groupby(['Group_Name']).get_group('Robbery - Property')
a.Sub_Group_Name.value_counts()
# Out:
# 2. Robbery    350
# Name: Sub_Group_Name, dtype: int64

# %%
a=stolen.groupby(['Group_Name']).get_group('Total Property')
a.Sub_Group_Name.value_counts()
# Out:
# 7. Total Property Stolen & Recovered    349
# Name: Sub_Group_Name, dtype: int64

# %%
#Since Sub_Group_Name is an irrelevant variable as previously proven ,we will use property1 as the base dataset
stolen1=stolen.drop(['Sub_Group_Name'],axis=1)

# %%
property_bystate=stolen1.groupby(['Area_Name'],as_index=False).sum()
property_bystate.drop("Year",axis=1,inplace=True)
plt.figure(figsize = (20, 10))
chart=sns.barplot(x=property_bystate.Area_Name,y=property_bystate.Cases_Property_Stolen)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart

# %%
#Cases of Property Stolen across the year of all the States 
sortbyyear=stolen1.groupby(['Year'],as_index=False).sum()
sortbyyear
plt.figure(figsize = (20, 10))
chart=sns.barplot(x=sortbyyear.Year,y=sortbyyear.Cases_Property_Stolen)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart

# %%
#Value of Property Stolen across the year of all the States 

plt.figure(figsize = (20, 10))
chart=sns.barplot(x=sortbyyear.Year,y=sortbyyear.Value_of_Property_Stolen)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart

# %%
plt.figure(figsize = (20, 10))
chart=sns.barplot(x=property_bystate.Area_Name,y=property_bystate.Value_of_Property_Stolen)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart

# %% [markdown]
# We can see that Maharashtra has the most no of stolen cases and the valu of stolen property is also high

# %%
a=stolen1.groupby(['Area_Name']).get_group('Maharashtra')
plt.figure(figsize = (20, 10))
chart=sns.barplot(x=a.Year,y=a.Value_of_Property_Stolen)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart

# %%
a=stolen1.groupby(['Area_Name']).get_group('Maharashtra')
plt.figure(figsize = (20, 10))
chart=sns.barplot(x=a.Year,y=a.Cases_Property_Stolen)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart

# %%
stolen.groupby(['Group_Name']).get_group('Robbery - Property')
# Out:
#                       Area_Name  Year          Group_Name Sub_Group_Name  \
# 1400  Andaman & Nicobar Islands  2001  Robbery - Property     2. Robbery
# 1401             Andhra Pradesh  2001  Robbery - Property     2. Robbery
# 1402          Arunachal Pradesh  2001  Robbery - Property     2. Robbery
# 1403                      Assam  2001  Robbery - Property     2. Robbery
# 1404                      Bihar  2001  Robbery - Property     2. Robbery
# 1405                 Chandigarh  2001  Robbery - Property     2. Robbery
# 1406               Chhattisgarh  2001  Robbery - Property     2. Robbery
# 1407       Dadra & Nagar Haveli  2001  Robbery - Property     2. Robbery
# 1408                Daman & Diu  2001  Robbery - Property     2. Robbery
# 1409                      Delhi  2001  Robbery - Property     2. Robbery
# 1410                        Goa  2001  Robbery - Property     2. Robbery
# 1411                    Gujarat  2001  Robbery - Property     2. Robbery
# ...

# %%
#Scatter plot
sns.scatterplot(x=stolen.Cases_Property_Recovered,y=stolen.Cases_Property_Stolen)

# %%
#difference of the Cases of Property Recovered from Total Cases of Property Stolen
property_bystate['Difference']=property_bystate["Cases_Property_Stolen"]- property_bystate["Cases_Property_Recovered"]
property_bystate
# Out:
#                     Area_Name  Cases_Property_Recovered  \
# 0   Andaman & Nicobar Islands                      1516
# 1              Andhra Pradesh                    332510
# 2           Arunachal Pradesh                      6048
# 3                       Assam                     54784
# 4                       Bihar                     63876
# 5                  Chandigarh                     15188
# 6                Chhattisgarh                     68912
# 7        Dadra & Nagar Haveli                      1170
# 8                 Daman & Diu                       534
# 9                       Delhi                    157858
# 10                        Goa                      5884
# 11                    Gujarat                    166644
# 12                    Haryana                    133320
# 13           Himachal Pradesh                      9798
# 14            Jammu & Kashmir                     22718
# 15                  Jharkhand                     35368
# ...

# %%
property_bystate['Percent_Recovery_Cases']=(property_bystate["Cases_Property_Recovered"]/ property_bystate["Cases_Property_Stolen"])*100

property_bystate.Percent_Recovery_Cases.sort_values()
# Out:
# 21     5.662983
# 4     15.509907
# 15    19.996834
# 3     22.309822
# 31    22.969613
# 34    23.044065
# 22    23.463286
# 24    24.653227
# 8     25.972763
# 13    28.817647
# 29    29.149065
# 18    29.532164
# 10    29.735193
# 28    30.058279
# 14    30.328679
# 32    30.545565
# 11    31.203236
# 9     32.170355
# 16    32.488161
# 17    32.964286
# 20    34.368186
# 6     34.505688
# 19    34.641811
# 33    35.063809
# 2     36.363636
# 5     38.237664
# 0     41.398143
# 12    43.951262
# 7     44.284633
# 25    46.404494
# 26    51.095813
# 1     51.726605
# 27    56.574195
# 23    70.266250
# 30    79.225867
# Name: Percent_Recovery_Cases, dtype: float64

# %% [markdown]
# 21(Manipur) has the lowest recovery rate.
# TamilNadu Police works more efficiantly with highest recovery rate of more than 79%.

# %%
property_bystate.Percent_Recovery_Cases.sort_values().mean()
# Out:
# 34.819519654956714

# %% [markdown]
# The mean recovery rate of stolen property is 34.81%.
